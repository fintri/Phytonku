# %% [markdown]
# <a href="https://colab.research.google.com/github/fintri/Phytonku/blob/main/PhytonEnigma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns ##Visualiasi
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/KennethParulian/PythonEDAEnigmacamp/main/Python%20Enigmacamp%20Datasource.csv'
link ='https://raw.githubusercontent.com/KennethParulian/PythonEDAEnigmacamp/main/dummydata_kendaraan.csv'
df = pd.read_csv(url)
link =pd.read_csv(link)

# %%
df.head(15)
# Out:
#     Unnamed: 0  ...                                        product_url
# 0            1  ...  https://www.tokopedia.com/shakaonline87/staple...
# 1            2  ...  https://www.tokopedia.com/juraganperkakas/stap...
# 2            3  ...  https://www.tokopedia.com/juraganperkakas/stap...
# 3            4  ...  https://www.tokopedia.com/kamarmesin/alat-stap...
# 4            5  ...  https://www.tokopedia.com/mitrapersada/isi-ref...
# 5            6  ...  https://www.tokopedia.com/mitrapersada/isi-ref...
# 6            7  ...  https://www.tokopedia.com/mitrapersada/isi-ref...
# 7            8  ...  https://www.tokopedia.com/mitrapersada/isi-ref...
# 8           10  ...  https://www.tokopedia.com/rumahbajukita/refill...
# 9           11  ...  https://www.tokopedia.com/rumahbajukita/refill...
# 10          12  ...  https://www.tokopedia.com/rumahbajukita/refill...
# 11          13  ...  https://www.tokopedia.com/rumahbajukita/refill...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40607 entries, 0 to 40606
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    40607 non-null  int64
#  1   text          40607 non-null  object
#  2   rating        40607 non-null  int64
#  3   category      40607 non-null  object
#  4   product_name  40607 non-null  object
#  5   product_id    40607 non-null  int64
#  6   sold          40593 non-null  object
#  7   shop_id       40607 non-null  int64
#  8   product_url   40607 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 2.8+ MB

# %%
jenis = df.groupby(['category'])['product_id'].count()

plt.bar(jenis.index, jenis)
plt.grid(linestyle='--', linewidth=2, axis='y',alpha = 0.3)
plt.ylabel("Jumlah Barang")
plt.xlabel("Jenis produk Tersedia")
plt.title("Jumlah produk yang ada berdasarkan kategori")
plt.show()

# %%
jumlahprodukterjual = df.groupby(['product_name'])['sold'].count().iloc[:20]
#jumlahprodukterjual.sort_values()
#jumlahprodukterjual
plt.barh(jumlahprodukterjual.index, jumlahprodukterjual , color = ['green','red'], alpha = 0.8)
plt.ylabel("nama produk")
plt.xlabel("Jumlah")
plt.title("Jumlah produk terjual pada 20 data pertama")
plt.show()

# %%
sns.countplot(x='category',data=df)

# %%
jumlahprodukterjualberdasarkanrating = df.groupby(['rating'])['sold'].count()
plt.bar(jumlahprodukterjualberdasarkanrating.index, jumlahprodukterjualberdasarkanrating)
plt.ylabel("jumlah")
plt.xlabel("rating")
plt.title("Jumlah produk terjual berdasarkan rating")
plt.show()

# %%
sns.countplot(x='model',data=link,order = pd.value_counts(link['model']).iloc[:5].index)
